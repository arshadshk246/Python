# %% [markdown]
# # Leetcode Exercises

# %%
from collections import Counter
import math
class Solution:
    def minOperations(self, nums):
        ele_count = Counter(nums)
        count = 0
        for value in ele_count.values():
            if value == 1:
                return -1
            count += math.ceil(value / 3)
        return count


nums = [2, 3, 3, 2, 2, 4, 2, 3, 4]
x = Solution()
x.minOperations(nums)
# Out:
# 4

# %%
class Solution:
    def twoSum(self, nums, target):

        dict1 = {}
        
        for i, value in enumerate(nums):
            required = target - nums[i]
            if required in dict1:
                return [i, dict1[required]]

            dict1[value] = i

x = Solution()
x.twoSum([2,7,11,15], 9)
# Out:
# [1, 0]

# %%
class Solution:
    def longestPalindrome(self, s: str) -> str:
        if len(s) <= 1:
            return s

        def expand_around_center(left, right):
            while left >= 0 and right < len(s) and s[left] == s[right]:
                left -= 1
                right += 1
            return s[left + 1:right]

        longest_palindrome = ""

        for i in range(len(s)):
            # Odd length palindrome
            palindrome_odd = expand_around_center(i, i)
            if len(palindrome_odd) > len(longest_palindrome):
                longest_palindrome = palindrome_odd

            # Even length palindrome
            palindrome_even = expand_around_center(i, i + 1)
            if len(palindrome_even) > len(longest_palindrome):
                longest_palindrome = palindrome_even

        return longest_palindrome
    
x = Solution()
x.longestPalindrome("babad")
# Out:
# 'bab'

# %%
class Solution:
    def isPalindrome(self, x: int) -> bool:
        
        return str(x) == str(x)[::-1]
    
x = Solution()
x.isPalindrome(121)
# Out:
# True

# %% [markdown]
# # OOP Concepts

# %% [markdown]
# ## Class

# %% [markdown]
# ### Class Attributes:

# %%
class Car:
    wheels = 4 # Attribute

    def __init__(self, name, company):
        self.name = name
        self.company = company

    def show(self):
        print(self.name, self.company, self.wheels)

car1 = Car("m5", "bmw")
car2 = Car("lancer", "mistubushi")
car1.show()
car2.show()
# Out:
# m5 bmw 4
# lancer mistubushi 4

# %% [markdown]
# ### Class Methods:

# %%
class Car:
    wheels = 4 

    def __init__(self, name, company):
        self.name = name
        self.company = company

    def show(self): # Class Methods
        print(self.name, self.company, self.wheels)
        
car1 = Car("m5", "bmw")
car2 = Car("lancer", "mistubushi")
car1.show() # Calling the class method show()
car2.show() # Calling the class method show()
# Out:
# m5 bmw 4
# lancer mistubushi 4

# %%
class Car:
    wheels = 4 

    def __init__(self, name, company):
        self.name = name
        self.company = company

    def show(self): # Class Methods
        print(self.name, self.company, self.wheels)

    @classmethod
    def increment_wheels(self):
        self.wheels += 1
        print(self.wheels)

car2 = Car("octavia", "skoda")
car2.increment_wheels()
# Out:
# 5

# %% [markdown]
# ### Static Methods

# %%
class MathOperations:
    @staticmethod
    def add(x, y):
        return x + y

MathOperations.add(3,4)
# Out:
# 7

# %% [markdown]
# ## Inheritence

# %%
class Animal:
    
    def speak(self):
        print("Some sound")

class Cat(Animal):

    def meow(self):
        print("😺 -- meow! meow!")

cat1 = Cat()
cat1.speak()
cat1.meow()
# Out:
# Some sound
# 😺 -- meow! meow!

# %%
# Multiple inheritance

class A:
    def method(self):
        print("A method")

class B(A):
    def method(self):
        print("B method")

class C(A):
    def method(self):
        print("C method")

class D(B, C):  
    pass

# Print the method resolution order
d = D()
print(d.method())
# Out:
# B method
# None

# %% [markdown]
# ## Dunder (Magic) Methods:

# %% [markdown]
# ### add()

# %%
# __add__()

class ComplexNumber:
    def __init__(self, real, imag):
        self.real = real
        self.imag = imag

    def __add__(self, other):
        return ComplexNumber(self.real + other.real, self.imag + other.imag)
    
num1 = ComplexNumber(real = 1, imag = 2)
num2 = ComplexNumber(real = 3, imag = 5)
res = num1 + num2
print(f"{res.real} + {res.imag}i")
# Out:
# 4 + 7i

# %% [markdown]
# ### len()

# %%
# __len__()

class MyList:
    def __init__(self, data):
        self.data = data

    def __len__(self):
        return len(self.data)

# Example usage:
my_list = MyList([1, 2, 3, 4, 5])
print(len(my_list))

# %% [markdown]
# ### iter()
# ### next()

# %%
#  iter()
#  next()

class MyRange:
    def __init__(self, start, end):
        self.start = start
        self.end = end
        self.current = start

    def __iter__(self):
        return self

    def __next__(self):
        if self.current >= self.end:
            raise StopIteration
        result = self.current
        self.current += 1
        return result

# Example usage:
my_range = MyRange(1, 5)
for num in my_range:
    print(num)
# Out:
# 1
# 2
# 3
# 4
